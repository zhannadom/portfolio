# %% [markdown]
# # Домашнее задание 5.2

# %% [markdown]
# # ✏️ 🗒️ 📝
#
# Сегодня тебе нужно выполнить задачу от руководительницы отдела контент-маркетинга новой онлайн-школы английского языка. Она хочет составить ТЗ копирайтеру на написание постов, но для этого ей нужно знать, какие типы постов популярны. За завтраком вы с ней обсуждали твое последнее занятие с курса Python, где мы парсили страницы сообществ ВК, и у вас появилась идея – проанализировать самые успешные посты известной онлайн-школы Skyeng  в [сообществе Skyeng в ВК](https://vk.com/skyeng).
#
# Теперь перед тобой стоит задача – выгрузить маркетологам для анализа 50 самых популярных постов за все время существования сообщества. Метрику популярности будем считать как сумму лайков, репостов и комментариев к каждому посту. Если останется время, для дополнительного анализа выгрузи все комментарии к этим постам в отдельный файл.

# %% [markdown]
# ## Задание 1
#
# Получи собственный `access_token` в ВК. Важно пройти этот путь самостоятельно, можешь использовать документацию API ВК или рекомендации из ноутбука занятия.  Токен присылай вместе с файлом ноутбука в файле с именем `my_own_token.py`. Обещаем не делать ничего противозаконного.
#
# *Если тебе некомфортно, можешь не присылать токен нам. Однако получить его все же обязательно – это необходимо для полноценного освоения темы урока, а также для выполнения заданий ниже.*

# %%
# читаем токен из файла my_own_token.py, куда мы сохранили access_token
from my_own_token import my_own_token as token

# %% [markdown]
# ## Задание 2
#
# __Сформируй запрос, который получает 100 записей со стены сообщества__
#
# 1. Найди в документации метод, который отдает все записи со стены сообщества Skyeng: https://vk.com/skyeng
# 2. Создай переменую для URL
# 3. Создай переменную с параметрами
# 4. Создай переменную запроса
# 5. Создай переменную, в которой будут данные ответа в формате словаря

# %%
import requests 
import pandas as pd

# %%
url = 'https://api.vk.com/method/wall.get'

params = {'access_token':token,
          'v':'5.131',
          'domain':'https://vk.com/skyeng',
          'filter':'all',
          'count':100
        }
req = requests.get(url,params).json()
res = req['response']['items']


print('Кол-во записей:', len(pd.DataFrame(res)))
# Out:
# Кол-во записей: 100

# %% [markdown]
# ## Задание 3
#
# Выгрузи в переменную `posts` в формате датафрейма __все записи__ сообщества Skyeng: https://vk.com/skyeng,
#
# 1. Используй цикл `While`
# 2. Для выгрузки __всех записей__ тебе поможет параметр `offset`.
# 3. Записей больше 7000! Не забудь про ограничение "не больше 3 запросов в секунду" от API VK, здесь тебе поможет библиотека `time`

# %%
# напиши здесь код
import time
offset = 0
counter = 100
posts = pd.DataFrame()

while True:      # Повторять цикл пока его не остановят по условию ниже
    
    url = 'https://api.vk.com/method/wall.get'
    params = {
        'domain':'skyeng',
        'access_token': token,
        'v':'5.131',
        'filter':'all',
        'count': counter,
        'offset': offset
    }
    
    req = requests.get(url=url,params=params).json()
    if len(req['response']['items']) != 0:      # Проверяем вернулись ли нам хоть какие-нибудь записи
        posts = pd.concat([posts,pd.DataFrame(req['response']['items'])])
    else:
        break     
                                  # Если нам ничего не вернулось, то прервать цикл
    print('Уже скачано', offset, 'записей')
    offset += counter               
    time.sleep(0.5)                             # Опять контролируем частоту запросов, чтобы нас не ограничили
# Out:
# Уже скачано 0 записей
# Уже скачано 100 записей
# Уже скачано 200 записей
# Уже скачано 300 записей
# Уже скачано 400 записей
# Уже скачано 500 записей
# Уже скачано 600 записей
# Уже скачано 700 записей
# Уже скачано 800 записей
# Уже скачано 900 записей
# Уже скачано 1000 записей
# Уже скачано 1100 записей
# Уже скачано 1200 записей
# Уже скачано 1300 записей
# Уже скачано 1400 записей
# Уже скачано 1500 записей
# Уже скачано 1600 записей
# Уже скачано 1700 записей
# Уже скачано 1800 записей
# Уже скачано 1900 записей
# Уже скачано 2000 записей
# Уже скачано 2100 записей
# Уже скачано 2200 записей
# Уже скачано 2300 записей
# Уже скачано 2400 записей
# Уже скачано 2500 записей
# Уже скачано 2600 записей
# Уже скачано 2700 записей
# Уже скачано 2800 записей
# Уже скачано 2900 записей
# Уже скачано 3000 записей
# Уже скачано 3100 записей
# Уже скачано 3200 записей
# Уже скачано 3300 записей
# Уже скачано 3400 записей
# Уже скачано 3500 записей
# Уже скачано 3600 записей
# Уже скачано 3700 записей
# Уже скачано 3800 записей
# Уже скачано 3900 записей
# Уже скачано 4000 записей
# Уже скачано 4100 записей
# Уже скачано 4200 записей
# Уже скачано 4300 записей
# Уже скачано 4400 записей
# Уже скачано 4500 записей
# Уже скачано 4600 записей
# Уже скачано 4700 записей
# Уже скачано 4800 записей
# Уже скачано 4900 записей
# Уже скачано 5000 записей
# Уже скачано 5100 записей
# Уже скачано 5200 записей
# Уже скачано 5300 записей
# Уже скачано 5400 записей
# Уже скачано 5500 записей
# Уже скачано 5600 записей
# Уже скачано 5700 записей
# Уже скачано 5800 записей
# Уже скачано 5900 записей
# Уже скачано 6000 записей
# Уже скачано 6100 записей
# Уже скачано 6200 записей
# Уже скачано 6300 записей
# Уже скачано 6400 записей
# Уже скачано 6500 записей
# Уже скачано 6600 записей
# Уже скачано 6700 записей
# Уже скачано 6800 записей
# Уже скачано 6900 записей
# Уже скачано 7000 записей
# Уже скачано 7100 записей
# Уже скачано 7200 записей
# Уже скачано 7300 записей
# Уже скачано 7400 записей
# Уже скачано 7500 записей
# Уже скачано 7600 записей
# Уже скачано 7700 записей
# Уже скачано 7800 записей
# Уже скачано 7900 записей

# %%
print('Кол-во записей:', len(posts))
# Out:
# Кол-во записей: 7952

# %%
posts

# %% [markdown]
# ## Задание 4
#
# Выгрузи 50 самых популярных постов. Метрикой популярности мы считаем сумму лайков, репостов и комментариев.
#
# 1. Создай столбцы с числовыми значениями для лайков, репостов и комментариев и забери из словаря только значение по ключу `count`
# 2. Создай отдельный столбец, где будет сумма пользовательских активностей для каждого поста
# 3. Отсортируй дата-фрейм по столбцу с суммой пользовательских активностей
# 4. Выбери 50 самых популярных постов
#
# Если задание кажется легким, реализуй тот же код с `lambda` функцией.

# %%
# вытащи из словарей столбцов comments, likes, reposts только нужные значения

# заполни даными с прошлого шага новые столбцы
posts['comments_count'] = posts['comments'].apply(lambda x: x['count'])
posts['likes_count'] = posts['likes'].apply(lambda x: x['count'])
posts['reposts_count'] = posts['reposts'].apply(lambda x: x['count'])

# %%
posts.head()
# Out:
#       id   from_id  owner_id        date  marked_as_ads post_type  \
# 0  86162 -51890028 -51890028  1645199315              0      post
# 1  86183 -51890028 -51890028  1645629644              0      post
# 2  86175 -51890028 -51890028  1645549668              0      post
# 3  86173 -51890028 -51890028  1645531172              0      post
# 4  86172 -51890028 -51890028  1645464282              0      post
#
#                                                 text  is_pinned  \
# 0  Никаких бритв, носков и гелей для душа 🙅🏼‍♀\nЛ...        1.0
# 1  С 2017-го в лондонском метро к пассажирам обра...        NaN
# 2  А что если сегодня тот самый день уникальных в...        NaN
# 3                                                           NaN
# 4  Вы решили изучать английский — что дальше? 🤯\n...        NaN
#
#                                          attachments     post_source  ...  \
# 0  [{'type': 'link', 'link': {'url': 'https://go....  {'type': 'vk'}  ...
# 1  [{'type': 'link', 'link': {'url': 'https://go....  {'type': 'vk'}  ...
# 2  [{'type': 'link', 'link': {'url': 'https://go....  {'type': 'vk'}  ...
# 3  [{'type': 'video', 'video': {'access_key': '49...  {'type': 'vk'}  ...
# 4  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
#
#   short_text_rate        edited                        hash carousel_offset  \
# 0             0.8  1.645200e+09  M1ItL4bc-_MLeyw-W5V56EutqA             NaN
# 1             0.8           NaN  SxQcqqNPJDFX8DiPsvYK46NzyA             NaN
# 2             0.8           NaN  Q6TaiqRK_uLDtUSlsU3Gg1p3jQ             NaN
# 3             0.8           NaN  l2rKkRxGo_kzNokVUkQb1GNwng             NaN
# 4             0.8           NaN  lmtsSaVPo71WZkkIyhXQzSfnrw             0.0
#
#    copy_history signer_id  geo  comments_count likes_count  reposts_count
# 0           NaN       NaN  NaN               0           2              2
# 1           NaN       NaN  NaN               3          12              6
# 2           NaN       NaN  NaN               6           4              1
# 3           NaN       NaN  NaN               2          13              4
# 4           NaN       NaN  NaN               0          10              4
#
# [5 rows x 26 columns]

# %%
# заполни данными столбец с суммой по всем активностям

posts['activity'] = posts['comments_count']+posts['likes_count']+posts['reposts_count']

# %%
posts.sort_values('activity', ascending=False, inplace=True)
popular_posts=posts[0:49]

# %%
popular_posts
# Out:
#        id   from_id  owner_id        date  marked_as_ads post_type  \
# 51  63081 -51890028 -51890028  1602590409              0      post
# 98  25259 -51890028 -51890028  1554800244              0      post
# 45    977 -51890028 -51890028  1416930109              0      post
# 86  75933 -51890028 -51890028  1604923204              0      post
# 77  42960 -51890028 -51890028  1568444249              0      post
# 42  48883 -51890028 -51890028  1574414757              0      post
# 49  31067 -51890028 -51890028  1561301735              0      post
# 82  55740 -51890028 -51890028  1587207600              0      post
# 10  51793 -51890028 -51890028  1581057787              0      post
# 36  57606 -51890028 -51890028  1589373062              0      post
# 2   60584 -51890028 -51890028  1596104809              0      post
# 43  46599 -51890028 -51890028  1569916801              0      post
# 46  53495 -51890028 -51890028  1583935214              0      post
# 74  61198 -51890028 -51890028  1597644180              0      post
# 31  49309 -51890028 -51890028  1574838003              0      post
# 97  58506 -51890028 -51890028  1591446471              0      post
# 68   1955 -51890028 -51890028  1424708125              0      post
# 45  53529 -51890028 -51890028  1583942411              0      post
# 47  59728 -51890028 -51890028  1593871472              0      post
# 57  29630 -51890028 -51890028  1560929039              0      post
# 73  80953 -51890028 -51890028  1609318604              0      post
# 0    1071 -51890028 -51890028  1417540800              0      post
# 87  52465 -51890028 -51890028  1582095606              0      post
# 26  49521 -51890028 -51890028  1575036060              0      post
# 66  83458 -51890028 -51890028  1614434940              0      post
# 24  54766 -51890028 -51890028  1585118114              0      post
# 86  50315 -51890028 -51890028  1576914557              0      post
# 98  82904 -51890028 -51890028  1613116047              0      post
# 63  83507 -51890028 -51890028  1614590078              0      post
# 61  56848 -51890028 -51890028  1588256830              0      post
# 76  25874 -51890028 -51890028  1555683420              0      post
# 32  61837 -51890028 -51890028  1599653403              0      post
# 47  83644 -51890028 -51890028  1615298700              0      post
# 73  59310 -51890028 -51890028  1592669785              0      post
# 52  30758 -51890028 -51890028  1561130880              0      post
# 53  57238 -51890028 -51890028  1588573020              0      post
# 45  81596 -51890028 -51890028  1611040740              0      post
# 92  58770 -51890028 -51890028  1591704289              0      post
# 6   41520 -51890028 -51890028  1567234808              0      post
# 29   5078 -51890028 -51890028  1450178421              0      post
# 94  80671 -51890028 -51890028  1608657060              0      post
# 63  61440 -51890028 -51890028  1598247960              0      post
# 44  23617 -51890028 -51890028  1552739280              0      post
# 65  28925 -51890028 -51890028  1560611851              0      post
# 88  83020 -51890028 -51890028  1613550503              0      post
# 64  59439 -51890028 -51890028  1593012000              0      post
# 96  25267 -51890028 -51890028  1554805320              0      post
# 70  59374 -51890028 -51890028  1592829812              0      post
# 96  84862 -51890028 -51890028  1622707174              0      post
#
#                                                  text  is_pinned  \
# 51  КОНКУРС! Выиграйте уроки английского и бьюти-б...        NaN
# 98  Через 15 дней вы накачаете пресс и выучите анг...        NaN
# 45  100 полезных английских фраз\nЭти фразы выруча...        NaN
# 86  КОНКУРС! Выиграйте уроки английского и боксы с...        NaN
# 77  😑Предлоги в английском — больная тема для всех...        NaN
# 42  Кот Виктор показывает, как стал причиной сканд...        NaN
# 49  Играем в слова. У кого словарный запас больше?...        NaN
# 82  Без фразовых глаголов можно понимать только са...        NaN
# 10  Английский снова сводит нас с ума, 😉и ему вооб...        NaN
# 36  Готовы ли вы к жизни в англоговорящем городе? ...        NaN
# 2             Подписывайтесь на [club51890028|Skyeng]        NaN
# 43                                 📚🤓Ну вы поняли.👇🏻😉        NaN
# 46                                                           NaN
# 74  Все самые главные фразовые глаголы в карточках...        NaN
# 31  Методисты онлайн-школы Skyeng составили чек-ли...        NaN
# 97  Простое объяснение всех времен в английском. \...        NaN
# 68  60 английских фраз на все случаи жизни\nТакого...        NaN
# 45  🎁 Ребят, мы тут конкурс затеяли. Подарим 2 БЕС...        NaN
# 47  58 фразовых глаголов на все случаи жизни! \n\n...        NaN
# 57  Теперь вы знаете, как отвечать:\n– How are you...        NaN
# 73  Новогодний словарик: 36 праздничных английских...        NaN
# 0   100 английских фраз для путешествий\nЭти фразы...        NaN
# 87  Наши методисты составили чек-лист: какие темы ...        NaN
# 26  ✅Приставки открывают сразу много новых слов пр...        NaN
# 66  58 фразовых глаголов 🔥🇬🇧\n\nМы собрали в одну ...        NaN
# 24                                      👉 Без паники!        NaN
# 86  Skyeng объясняет как не запутаться в английско...        NaN
# 98  5 важных предлогов в английском 🔥🇬🇧\n\nПредлог...        NaN
# 63  Не путайте предлоги: полезные карточки 🇬🇧📌\n\n...        NaN
# 61  Идея на майские.💡80 иностранных фильмов для пр...        NaN
# 76  Раз в неделю, мы и [club130552184|Topsify] пре...        NaN
# 32  Английские предлоги не поддаются каким-либо пр...        NaN
# 47  Синонимы к фразе «I like» 😍 Сохраняйте себе и ...        NaN
# 73  Синонимы к прилагательным happy, good и beauti...        NaN
# 52  Мы любим разбирать Карди Би. Это как будто выу...        NaN
# 53  Хвалите себя чаще! \n\n❓ Расскажите, как вы пр...        NaN
# 45  В чем разница между словами say, tell, speak и...        NaN
# 92  Напишите в комментариях цифру от 1 до 7. Фраза...        NaN
# 6   😃Билли Айлиш проспала премию Video Music Award...        NaN
# 29  Skyeng Steps — бесплатный курс разговорного ан...        NaN
# 94  5 самых важных времен в английском \n\nВ англи...        NaN
# 63  Английские синонимы, в которых уже заложено ус...        NaN
# 44  Дэни собрал для вас самый топовый американский...        NaN
# 65  Вы можете учить английский вообще бесплатно и ...        NaN
# 88  В чем разница между must и should? А когда исп...        NaN
# 64               В вашу видео-копилку на выходные. 👇🏻        NaN
# 96  Дэни собрал для вас самый топовый американский...        NaN
# 70  Фразовые глаголы со словом get, которые должен...        NaN
# 96  Английские предлоги не поддаются каким-либо пр...        NaN
#
#                                           attachments  \
# 51  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 98  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 45  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 86  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 77  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 42  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 49  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 82  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 10  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 36  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 2   [{'type': 'photo', 'photo': {'album_id': -7, '...
# 43  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 46  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 74  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 31  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 97  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 68  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 45  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 47  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 57  [{'type': 'video', 'video': {'access_key': '4f...
# 73  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 0   [{'type': 'photo', 'photo': {'album_id': -7, '...
# 87  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 26  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 66  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 24  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 86  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 98  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 63  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 61  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 76  [{'type': 'link', 'link': {'url': 'https://m.v...
# 32  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 47  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 73  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 52  [{'type': 'link', 'link': {'url': 'https://m.v...
# 53  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 45  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 92  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 6   [{'type': 'photo', 'photo': {'album_id': -7, '...
# 29  [{'type': 'link', 'link': {'url': 'http://scho...
# 94  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 63  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 44  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 65  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 88  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 64  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 96  [{'type': 'doc', 'doc': {'id': 497691275, 'own...
# 70  [{'type': 'photo', 'photo': {'album_id': -7, '...
# 96  [{'type': 'photo', 'photo': {'album_id': -7, '...
#
#                                post_source  ...        edited  \
# 51                          {'type': 'vk'}  ...           NaN
# 98                          {'type': 'vk'}  ...  1.554800e+09
# 45                          {'type': 'vk'}  ...  1.416991e+09
# 86                          {'type': 'vk'}  ...           NaN
# 77                          {'type': 'vk'}  ...  1.568449e+09
# 42                          {'type': 'vk'}  ...           NaN
# 49                          {'type': 'vk'}  ...  1.561308e+09
# 82                          {'type': 'vk'}  ...           NaN
# 10                          {'type': 'vk'}  ...  1.581063e+09
# 36                          {'type': 'vk'}  ...           NaN
# 2                           {'type': 'vk'}  ...  1.596128e+09
# 43                          {'type': 'vk'}  ...           NaN
# 46                          {'type': 'vk'}  ...           NaN
# 74                          {'type': 'vk'}  ...           NaN
# 31                          {'type': 'vk'}  ...  1.574869e+09
# 97                          {'type': 'vk'}  ...           NaN
# 68                          {'type': 'vk'}  ...           NaN
# 45                          {'type': 'vk'}  ...  1.583951e+09
# 47                          {'type': 'vk'}  ...           NaN
# 57                          {'type': 'vk'}  ...  1.560929e+09
# 73                          {'type': 'vk'}  ...           NaN
# 0                           {'type': 'vk'}  ...           NaN
# 87                          {'type': 'vk'}  ...           NaN
# 26                          {'type': 'vk'}  ...  1.575041e+09
# 66                          {'type': 'vk'}  ...           NaN
# 24  {'platform': 'android', 'type': 'api'}  ...           NaN
# 86                          {'type': 'vk'}  ...           NaN
# 98                          {'type': 'vk'}  ...           NaN
# 63                          {'type': 'vk'}  ...           NaN
# 61                          {'type': 'vk'}  ...  1.588258e+09
# 76                          {'type': 'vk'}  ...  1.555690e+09
# 32                          {'type': 'vk'}  ...           NaN
# 47                          {'type': 'vk'}  ...           NaN
# 73                          {'type': 'vk'}  ...           NaN
# 52                          {'type': 'vk'}  ...           NaN
# 53                          {'type': 'vk'}  ...           NaN
# 45                          {'type': 'vk'}  ...           NaN
# 92                          {'type': 'vk'}  ...  1.591706e+09
# 6                           {'type': 'vk'}  ...           NaN
# 29                          {'type': 'vk'}  ...           NaN
# 94                          {'type': 'vk'}  ...           NaN
# 63                          {'type': 'vk'}  ...           NaN
# 44                          {'type': 'vk'}  ...           NaN
# 65                          {'type': 'vk'}  ...           NaN
# 88                          {'type': 'vk'}  ...           NaN
# 64                          {'type': 'vk'}  ...           NaN
# 96                          {'type': 'vk'}  ...           NaN
# 70                          {'type': 'vk'}  ...  1.592854e+09
# 96                          {'type': 'vk'}  ...           NaN
#
#                           hash carousel_offset copy_history  signer_id  geo  \
# 51  bkSaz5CnxvJn-DbRjeQEt5sp-A             0.0          NaN        NaN  NaN
# 98  tx_dPa46FuTQYXE98l4wQumtdw             0.0          NaN        NaN  NaN
# 45  a_NEs2C5iZa-Xa_jf0kKbZY4Jw             0.0          NaN        NaN  NaN
# 86  Ow42GQjTLV6qg-xz87lmJfykIA             0.0          NaN        NaN  NaN
# 77  -Fq7e4wYy8wTzvluIupKUs1ihA             0.0          NaN        NaN  NaN
# 42  9F_Bz54vBN_m4N6Zm_CQpzmgkw             NaN          NaN        NaN  NaN
# 49  LazF9OFm3-zFuHUPM_Quub8xgg             NaN          NaN        NaN  NaN
# 82  gS-c2E-H2lH3Gmc0IS9oRbFnFQ             0.0          NaN        NaN  NaN
# 10  k7HaUOV-zniwP6ITgKGy09DcyA             0.0          NaN        NaN  NaN
# 36  uWFaN7cb1zaNAdNzm6_QeM1hlA             0.0          NaN        NaN  NaN
# 2   N4dqVMfhXf4_AM95id4SHj2y4w             NaN          NaN        NaN  NaN
# 43  2NUHsRAq0fCW8t4U_-vtXsulRQ             0.0          NaN        NaN  NaN
# 46  lClFY5S9oT6vYBtRQsFkUMorPQ             NaN          NaN        NaN  NaN
# 74  NzDoecdqCPo5B4FAqBvRFKdpBA             0.0          NaN        NaN  NaN
# 31  0vMi-g8ocecSgtK229Gn0Syuew             0.0          NaN        NaN  NaN
# 97  NbNW7ZW-FeBfIvCUzxYPMrdSGQ             NaN          NaN        NaN  NaN
# 68  lhMJKSVzEmeiV4InnjjDwEhlqQ             0.0          NaN        NaN  NaN
# 45  AarSjrtnuGM9u7SoLnURKADcLw             NaN          NaN        NaN  NaN
# 47  oKkHwzxIUcmVtl0rv7ICxayjtQ             0.0          NaN        NaN  NaN
# 57  RaZm7Z58yD99EnfUEJVknYuStQ             NaN          NaN        NaN  NaN
# 73  oyKJ3tt2EdhfWkZwoT8Dgyve1A             0.0          NaN        NaN  NaN
# 0   1stK7sXYA3oagFLwHU3t1D8ruw             0.0          NaN        NaN  NaN
# 87  RQU-8UQ17qfOMYZiLxbx-WF5Ag             0.0          NaN        NaN  NaN
# 26  c06QLrJeIZio3-EKNtwrufc5xw             0.0          NaN        NaN  NaN
# 66  Ic9SJlKSIDL0noycoSnlROxSpw             0.0          NaN        NaN  NaN
# 24  rX1KTqsjexsVwtTMXSUYf2HX8w             NaN          NaN        NaN  NaN
# 86  MpbxxeXGj_vr7IyY4s90lXGZtA             0.0          NaN        NaN  NaN
# 98  ySt6Z8jU-R9gOGolDvApeZ6DBg             0.0          NaN        NaN  NaN
# 63  30O2wLPTA6XcRhYhsJ1EC2QTJA             0.0          NaN        NaN  NaN
# 61  0IlDM_J_VIUeNcatLSitAYZLDQ             0.0          NaN        NaN  NaN
# 76  5E3aGFIIubFnlCKSlZWKRETwUw             0.0          NaN        NaN  NaN
# 32  mWhZGU5zctCme2cjwhClAirdJQ             0.0          NaN        NaN  NaN
# 47  7TyrrTCeJCAlkk02L0W_cQZV-g             NaN          NaN        NaN  NaN
# 73  4cqza1dTxvCs7zwrEMg3Dve1iw             NaN          NaN        NaN  NaN
# 52  DUgCx17vqCLh6hL3Qj285SkW1w             0.0          NaN        NaN  NaN
# 53  fxVvMBrkkasNFfGHAP-IczOnJw             NaN          NaN        NaN  NaN
# 45  BXOCPt7tIvy4uDp79GjDdUU_fA             NaN          NaN        NaN  NaN
# 92  cEql1puv7tals9Vt4GnJHMovEw             NaN          NaN        NaN  NaN
# 6   qiHW-yobG1euYjKeY_8IDioNfA             NaN          NaN        NaN  NaN
# 29  mzKVQkxIMAIfUiWpa3OVlwS0Zg             NaN          NaN        NaN  NaN
# 94  -X5CLOqgamhpgPklkrAbSuAHOg             0.0          NaN        NaN  NaN
# 63  RehX6NeIWZDewHUn38KdmM14Tw             NaN          NaN        NaN  NaN
# 44  Aodm3Y20EfDVDbZx5_99x26mDQ             NaN          NaN        NaN  NaN
# 65  599CmBfhMz7dq3vpc3g_KwxYjg             NaN          NaN        NaN  NaN
# 88  -XG41I2xQlfM4xHYtb2emzj5Jw             0.0          NaN        NaN  NaN
# 64  DhYjBnmIRmikW-sPl2ayd7UW7A             NaN          NaN        NaN  NaN
# 96  IoLSgxVKFf9IXNWbDlmtIDek8A             NaN          NaN        NaN  NaN
# 70  GeAd75Nb-3UyToiSVmtvk2Solw             0.0          NaN        NaN  NaN
# 96  QFcxOMZ1DRklF08To1GeHpqniQ             0.0          NaN        NaN  NaN
#
#     comments_count  likes_count reposts_count  activity
# 51           10962          117             2     11081
# 98             239         6996          1446      8681
# 45               0         4012           975      4987
# 86            2891          133             6      3030
# 77              50         1917           435      2402
# 42              54         1620           210      1884
# 49            1634          135             3      1772
# 82              36         1397           275      1708
# 10             111         1383           198      1692
# 36              84         1479           124      1687
# 2               26         1457           158      1641
# 43              44         1426            81      1551
# 46              66         1424            59      1549
# 74              18         1208           239      1465
# 31              35         1174           232      1441
# 97             104         1186           142      1432
# 68               0         1059           233      1292
# 45             661          586             9      1256
# 47              69          955           201      1225
# 57             132         1024            31      1187
# 73               0          655           519      1174
# 0                0          883           275      1158
# 87              26          890           173      1089
# 26               8          900           173      1081
# 66               3          517           524      1044
# 24              38          894            29       961
# 86              20          828           100       948
# 98               8          474           456       938
# 63               0          453           478       931
# 61              47          727           122       896
# 76              27          811            26       864
# 32               6          702           138       846
# 47              11          569           259       839
# 73              10          694           128       832
# 52              79          696            53       828
# 53              22          717            71       810
# 45               2          444           364       810
# 92              74          664            71       809
# 6               58          727            24       809
# 29               0          658           134       792
# 94               0          396           381       777
# 63               9          664           102       775
# 44              28          674            72       774
# 65             196          557             2       755
# 88              32          392           328       752
# 64              32          655            65       752
# 96              41          643            52       736
# 70              11          622            99       732
# 96               0          360           372       732
#
# [49 rows x 27 columns]

# %% [markdown]
# ## Задание 5
#
# __Почисти данные, сохрани результат в файл для отправки копирайтерам__
#
# 1. Отфильтруй в датафрейме только нужные столбцы:
#     - дата поста
#     - текст поста
#     - количество комментариев
#     - количество лайков
#     - количество репостов
#     - общее количество пользовательских активностей
#
# 2. Выгрузи датафрейм в .csv файл

# %%
# напиши здесь код
popular_posts_for_copywriters=popular_posts[['date','text','comments_count','likes_count','reposts_count','activity']]
popular_posts_for_copywriters.to_csv('popular_posts_for_copywriters.csv',index=False)

# %% [markdown]
# ## EXTRA
#
# __К 50 самым популярным постам выгрузи все комментарии, чтобы оценить, как пользователи восприняли посты__
#
# 1. Создай цикл, который проходит по всем `post ID`
# 2. В каждом цикле собери все комментарии к посту, используя `offset`
# 3. В каждом цикле достань лайки в отдельный столбец
# 4. Собери все комментарии в одном датафрейме
#
#
#
# *Обрати внимание, что для работы с постами нужны __дополнительные параметры в токене__*

# %% [markdown]
# # 🎉🎉🎉 Поздравляем, ты великолепен!
